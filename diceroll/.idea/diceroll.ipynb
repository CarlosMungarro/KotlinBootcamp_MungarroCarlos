// %%
println("=== Dice Roll Lambdas ===")

// 4. Con notación de tipo función (incluye todo lo anterior)
val rollDice2: (Int) -> Int = { sides ->
    if (sides > 0) (1..sides).random() else 0
}

// Probar
println("Dado de 6 lados: ${rollDice2(6)}")
println("Dado de 12 lados: ${rollDice2(12)}")
println("Dado de 0 lados: ${rollDice2(0)}")
// Out:
// === Dice Roll Lambdas ===
// Dado de 6 lados: 3
// Dado de 12 lados: 4
// Dado de 0 lados: 0

// %%
println("\n=== GamePlay Function ===")

// 1. Razón para notación de tipo función:
println("La notación de tipo función hace el código más claro y explícito.")

// 2. Función gamePlay
fun gamePlay(roll: (Int) -> Int) {
    val result = roll(6) // Siempre dado de 6 lados
    println(" Lanzamiento: $result")
}

// 3. Usar rollDice2 en gamePlay
println("\nJugando 3 veces:")
repeat(3) {
    gamePlay(rollDice2)
}
// Out:
// Jugando 3 veces:
// 🎲 Lanzamiento: 1
// 🎲 Lanzamiento: 1
// 🎲 Lanzamiento: 2
